# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/syedali287/flyrank-intern/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
'''My lane is a ranking/scoring problem.

The goal is not simply to predict whether content is declining or not. The real goal is to help prioritize which content should be reviewed first.

The model output would be a priority score that ranks content items from highest urgency to lowest urgency for refresh or review.'''
# Out:
# 'My lane is a ranking/scoring problem.\n\nThe goal is not simply to predict whether content is declining or not. The real goal is to help prioritize which content should be reviewed first.\n\nThe model output would be a priority score that ranks content items from highest urgency to lowest urgency for refresh or review.'

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
''' The target is the likelihood that a content item is declining in performance.

For the starter dataset, a practical proxy target is:

is_declining_label

However, this label is derived from trend_direction, which itself comes from trend_pct.

Because of this, trend_direction and trend_pct must never be used as features.

The target is observed in the dataset and represents an outcome rather than a manually written rule.'''
# Out:
# ' The target is the likelihood that a content item is declining in performance.\n\nFor the starter dataset, a practical proxy target is:\n\nis_declining_label\n\nHowever, this label is derived from trend_direction, which itself comes from trend_pct.\n\nBecause of this, trend_direction and trend_pct must never be used as features.\n\nThe target is observed in the dataset and represents an outcome rather than a manually written rule.'

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
''' Since this is a ranking task, the primary success metric is:

Precision@K

The question is:

Of the top K pages that the model recommends for refresh, how many actually needed attention?

A secondary metric could be recall, but Precision@K better matches the business decision because editor time is limited. '''
# Out:
# ' Since this is a ranking task, the primary success metric is:\n\nPrecision@K\n\nThe question is:\n\nOf the top K pages that the model recommends for refresh, how many actually needed attention?\n\nA secondary metric could be recall, but Precision@K better matches the business decision because editor time is limited. '

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
'''The decision being improved is:

Which pages should an editor refresh first?

This is not a prediction problem for its own sake.

The output helps prioritize work so that editors spend time on pages that matter most.


Unit of Analysis

One row in the dataframe represents:

One content item.

Example:

content_id	   client_id	  ctr	        engagement_rate	      avg_position
   101	           5	     0.82	            3.1	                 14.5
102	               5	     1.12	            4.0	                  8.2
103	               9	     0.41	            2.3	                 28.7

Therefore:

One row = one content item observed over the trailing 90-day window.'''
# Out:
# 'The decision being improved is:\n\nWhich pages should an editor refresh first?\n\nThis is not a prediction problem for its own sake.\n\nThe output helps prioritize work so that editors spend time on pages that matter most.'

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
'''A simple rule could be:

Refresh every page with traffic below a fixed threshold.

However, content performance depends on many interacting signals:

CTR
Engagement rate
Scroll rate
Position changes
Content type
Historical performance

These relationships are messy and change over time.

Machine learning can combine many weak signals into a better prioritization score than a manually written rule.

'''
# Out:
# 'A simple rule could be:\n\nRefresh every page with traffic below a fixed threshold.\n\nHowever, content performance depends on many interacting signals:\n\nCTR\nEngagement rate\nScroll rate\nPosition changes\nContent type\nHistorical performance\n\nThese relationships are messy and change over time.\n\nMachine learning can combine many weak signals into a better prioritization score than a manually written rule.\n\nUnit of Analysis\n\nOne row in the dataframe represents:\n\nOne content item.\n\nExample:\n\ncontent_id\t   client_id\t  ctr\t        engagement_rate\t      avg_position\n   101\t           5\t     0.82\t            3.1\t                 14.5\n102\t               5\t     1.12\t            4.0\t                  8.2\n103\t               9\t     0.41\t            2.3\t                 28.7\n\nTherefore:\n\nOne row = one content item observed over the trailing 90-day window.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [yes] Every section above is filled — markdown thinking AND the code that backs it
# - [yes] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [yes] No client names, URLs, or private queries anywhere
# - [yes] My claims use careful words: observed, measured, directional, decision-support
# - [yes] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
